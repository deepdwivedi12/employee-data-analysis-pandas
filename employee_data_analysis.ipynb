# %% [markdown]
# **IMPORT FILE**

# %%
import pandas as pd
df = pd.read_csv("/content/employees (1).csv")

# %%
df
# Out:
#     First Name  Last Name                                    Email  \
# 0         Jose      Lopez           joselopez0944@slingacademy.com
# 1        Diane     Carter         dianecarter1228@slingacademy.com
# 2        Shawn     Foster         shawnfoster2695@slingacademy.com
# 3       Brenda     Fisher        brendafisher3185@slingacademy.com
# 4         Sean     Hunter          seanhunter4753@slingacademy.com
# ..         ...        ...                                      ...
# 315   Michelle     Hooper    michellehooper315396@slingacademy.com
# 316     Steven      Lewis       stevenlewis316274@slingacademy.com
# 317      Kevin  Rodriguez    kevinrodriguez317974@slingacademy.com
# 318  Alexandra       Bell     alexandrabell318109@slingacademy.com
# 319   Courtney   Mcdaniel  courtneymcdaniel319568@slingacademy.com
#
#                       Phone  Gender  Age                  Job Title  \
# 0      +1-971-533-4552x1542    male   25            Project Manager
# ...

# %%
print(df.head())
# Out:
#   First Name Last Name                              Email  \
# 0       Jose     Lopez     joselopez0944@slingacademy.com
# 1      Diane    Carter   dianecarter1228@slingacademy.com
# 2      Shawn    Foster   shawnfoster2695@slingacademy.com
# 3     Brenda    Fisher  brendafisher3185@slingacademy.com
# 4       Sean    Hunter    seanhunter4753@slingacademy.com
#
#                   Phone  Gender  Age                  Job Title  \
# 0  +1-971-533-4552x1542    male   25            Project Manager
# 1          881.633.0107  female   26  Machine Learning Engineer
# 2  001-966-861-0065x493    male   37            Project Manager
# 3      001-574-564-4648  female   31              Web Developer
# 4            5838355842    male   35            Project Manager
#
#    Years Of Experience  Salary Department
# 0                    1    8500    Product
# 1                    2    7000    Product
# 2                   14   17000    Product
# 3                    8   10000    Product
# ...

# %% [markdown]
# df.head() # first 5 rows
# df.tail() # last 5 rows
# df.shape() # rows, columns
# df.columns # column
# df.info() # data type
# df.describe() # summary statistics

# %%
print(df.tail())
# Out:
#     First Name  Last Name                                    Email  \
# 315   Michelle     Hooper    michellehooper315396@slingacademy.com
# 316     Steven      Lewis       stevenlewis316274@slingacademy.com
# 317      Kevin  Rodriguez    kevinrodriguez317974@slingacademy.com
# 318  Alexandra       Bell     alexandrabell318109@slingacademy.com
# 319   Courtney   Mcdaniel  courtneymcdaniel319568@slingacademy.com
#
#                       Phone  Gender  Age      Job Title  Years Of Experience  \
# 315            401.041.6802  female   29  Web Developer                    4
# 316     +1-584-489-5663x896    male   34  Web Developer                   11
# 317  001-511-226-4416x83410    male   29  Web Developer                    5
# 318     +1-426-702-6363x565  female   39  Web Developer                   14
# 319     (871)098-2647x80448  female   28  Web Developer                    3
#
#      Salary Department
# 315    9000    Product
# 316   11500    Product
# 317    8500    Product
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 320 entries, 0 to 319
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   First Name           320 non-null    object
#  1   Last Name            320 non-null    object
#  2   Email                320 non-null    object
#  3   Phone                320 non-null    object
#  4   Gender               320 non-null    object
#  5   Age                  320 non-null    int64
#  6   Job Title            320 non-null    object
#  7   Years Of Experience  320 non-null    int64
#  8   Salary               320 non-null    int64
#  9   Department           320 non-null    object
# dtypes: int64(3), object(7)
# memory usage: 25.1+ KB
# None

# %%
print(df.describe())
# Out:
#               Age  Years Of Experience        Salary
# count  320.000000           320.000000    320.000000
# mean    31.587500             7.687500  10175.000000
# std      4.607323             4.428729   2615.483196
# min     23.000000             1.000000   5500.000000
# 25%     28.000000             4.000000   8000.000000
# 50%     32.000000             7.500000  10000.000000
# 75%     35.000000            12.000000  12000.000000
# max     41.000000            15.000000  17000.000000

# %%
average_salary = df['Salary'].mean()
max_salary = df['Salary'].max()
min_salary = df['Salary'].min()

print("Average Salary:", average_salary)
print("Maximum Salary:", max_salary)
print("Minimum Salary:", min_salary)
# Out:
# Average Salary: 10175.0
# Maximum Salary: 17000
# Minimum Salary: 5500

# %%
total_employes = df.shape[0]
average_salary = df['Salary'].mean()
max_salary = df['Salary'].max()
min_salary = df['Salary'].min()


print("Total employes:", total_employes)
print("Average Salary:", average_salary)
print("Highest Salary:",max_salary)
print("Lowest Salary:",min_salary)
# Out:
# Total employes: 320
# Average Salary: 10175.0
# Highest Salary: 17000
# Lowest Salary: 5500

# %% [markdown]
# df.shape() = rows and columns (5,5)
#  df.columns = columns name<!--imutable -->
# df.info = data() type
# df.describe() = statisctics

# %%
high_salary = df[df["Salary"] > 15000]
high_salary[["First Name","Department","Salary"]]
# Out:
#     First Name Department  Salary
# 2        Shawn    Product   17000
# 42      Alyssa    Product   15500
# 59       Aaron    Product   16500
# 82     Michael    Product   16000
# 96    Patricia    Product   16500
# 120  Stephanie    Product   15500
# 123      Logan    Product   16000
# 124       Ryan    Product   15500
# 130       Cody    Product   15500
# 151     Austin    Product   16500
# 204    Michael    Product   15500

# %%
dept_salary = df.groupby('Department')['Salary'].mean().sort_values(ascending = True)
print(dept_salary)
# Out:
# Department
# Human Resource     9850.000000
# Product           10185.483871
# Name: Salary, dtype: float64

# %% [markdown]
# **DATA INPECTION**

# %%
import pandas as pd
df = pd.read_csv("/content/employees (1).csv")
df.shape
# Out:
# (320, 10)

# %% [markdown]
# **DATA UNDERSTANING**
# df.info()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 320 entries, 0 to 319
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   First Name           320 non-null    object
#  1   Last Name            320 non-null    object
#  2   Email                320 non-null    object
#  3   Phone                320 non-null    object
#  4   Gender               320 non-null    object
#  5   Age                  320 non-null    int64
#  6   Job Title            320 non-null    object
#  7   Years Of Experience  320 non-null    int64
#  8   Salary               320 non-null    int64
#  9   Department           320 non-null    object
# dtypes: int64(3), object(7)
# memory usage: 25.1+ KB

# %% [markdown]
# df.dtypes

# %%
df.dtypes
# Out:
# First Name             object
# Last Name              object
# Email                  object
# Phone                  object
# Gender                 object
# Age                     int64
# Job Title              object
# Years Of Experience     int64
# Salary                  int64
# Department             object
# dtype: object

# %%
df.nunique()#UNIQUE VALUES n-total number of unique value
# Out:
# First Name             186
# Last Name              237
# Email                  320
# Phone                  320
# Gender                   2
# Age                     19
# Job Title                8
# Years Of Experience     15
# Salary                  24
# Department               2
# dtype: int64

# %%
df.isnull().sum() # MISSING VALUES KO CHECK KARNA
# Out:
# First Name             0
# Last Name              0
# Email                  0
# Phone                  0
# Gender                 0
# Age                    0
# Job Title              0
# Years Of Experience    0
# Salary                 0
# Department             0
# dtype: int64

# %%
df.dropna(inplace = True) # REMOVE MISSING VALUES // inplace true -

# %%
df["Salary"].fillna(df["Salary"].mean(),inplace = True) # FILL MISSING VALUES
# Out:
# /tmp/ipykernel_3278/2052560777.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Salary"].fillna(df["Salary"].mean(),inplace = True) # FILL MISSING VALUES

# %%
df.duplicated().sum()
df.drop_duplicates(inplace=True) # DUPLICATES

# %% [markdown]
# **DATA TRANSFORMATION**

# %%
df.rename(columns={"emp_name": "Name"},inplace=True) #RENAME COLUMNS

# %%
df["Age"] = df["Age"].astype(int) #CHANGE DATA TYPE

# %%
df["Bonus"] = df["Salary"] * 0.1 #CRATE NEW COLUMN

# %% [markdown]
# **ANALYSIS AND INTERPRETATION**

# %%
df["Salary"].mean()
# Out:
# np.float64(10175.0)

# %%
df["Salary"].max()
# Out:
# 17000

# %%
df.groupby("Department")["Salary"].mean()
# Out:
# Department
# Human Resource     9850.000000
# Product           10185.483871
# Name: Salary, dtype: float64

# %%
df[df["Salary"] > 15000]
# Out:
#     First Name Last Name                                 Email  \
# 2        Shawn    Foster      shawnfoster2695@slingacademy.com
# 42      Alyssa    Archer    alyssaarcher42600@slingacademy.com
# 59       Aaron      Tran       aarontran59178@slingacademy.com
# 82     Michael    Davila   michaeldavila82958@slingacademy.com
# 96    Patricia    Suarez  patriciasuarez96379@slingacademy.com
# 120  Stephanie      Hill  stephaniehill120240@slingacademy.com
# 123      Logan   Edwards   loganedwards123515@slingacademy.com
# 124       Ryan     Young      ryanyoung124775@slingacademy.com
# 130       Cody    Zuniga     codyzuniga130555@slingacademy.com
# 151     Austin      Bell     austinbell151766@slingacademy.com
# 204    Michael    Hoover  michaelhoover204983@slingacademy.com
#
#                       Phone  Gender  Age        Job Title  \
# 2      001-966-861-0065x493    male   37  Project Manager
# 42   001-335-037-7267x43704  female   35  DevOps Engineer
# ...

# %% [markdown]
# **Simple Data Visualization**

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("/content/employees.csv")
df["Age"].hist()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
df["Salary"].hist()
plt.title("Salary Distribution")
plt.xlabel("Salary")
plt.ylabel("Number of employe")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(x = df["Salary"])
plt.title("Salary Box Plot")
plt.show()

# %%
text = "Python"
text[-2:-6:-3]
# Out:
# 'oy'

# %%
text = "Deep"
print(text[:])
# Out:
# Deep

# %%
text = "Hello World"
text[2:11]
# Out:
# 'llo World'

# %%
text = "text hey are you there"
text[-2:-15:-1]
# Out:
# 'reht uoy era '

# %%
text[::-1]
# Out:
# 'ereht uoy era yeh txet'

# %% [markdown]
# **SORTING**

# %%
marks = [39,48,32,48,88]
marks.sort()
print(marks)
# Out:
# [32, 39, 48, 48, 88]

# %%
marks = [39,48,32,48,88]
# marks.sort(reverse=False)
marks.sort(reverse=True)
print(marks)
# print(marks)
# Out:
# [88, 48, 48, 39, 32]

# %%
marks = [56,38,89,27]

new_marks = sorted(marks)
print(new_marks)
print(marks)
# Out:
# [27, 38, 56, 89]
# [56, 38, 89, 27]

# %%
names = ["Deep", "Anuj","rohan","hii"]
names.sort()
print(names)
# Out:
# ['Anuj', 'Deep', 'hii', 'rohan']

# %%
import pandas as pd
df = pd.DataFrame({
    "Name":["A","B","C"],
    "Age" : [21,22,23]
})
print(df.sort_values("Age"))
# Out:
#   Name  Age
# 0    A   21
# 1    B   22
# 2    C   23

# %%
df.sort_values("age" ascending=False)
# Out:
#   File "/tmp/ipykernel_1006/3041714254.py", line 1
#     df.sort_values("age" ascending=False)
#                    ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from scipy.stats import ttest_ind

# Sample Dataset
data = {
    "Hours": [1, 2, 3, 4, 5, 6],
    "Marks": [20, 30, 40, 50, 60, 70]
}

df = pd.DataFrame(data)

print("Dataset")
print(df)

# Correlation
print("\nCorrelation Matrix")
print(df.corr())

# Linear Regression
X = df[["Hours"]]
Y = df["Marks"]

model = LinearRegression()
model.fit(X, Y)

prediction = model.predict([[7]])

print("\nPredicted Marks for 7 Hours Study:")
print(prediction[0])

# Hypothesis Testing (T-Test)

group1 = [20, 30, 40, 50]
group2 = [25, 35, 45, 55]

t_stat, p_value = ttest_ind(group1, group2)

print("\nT-Test Result")
print("T-Statistic =", t_stat)
print("P-Value =", p_value)
# Out:
# Dataset
#    Hours  Marks
# 0      1     20
# 1      2     30
# 2      3     40
# 3      4     50
# 4      5     60
# 5      6     70
#
# Correlation Matrix
#        Hours  Marks
# Hours    1.0    1.0
# Marks    1.0    1.0
#
# Predicted Marks for 7 Hours Study:
# 80.0
#
# T-Test Result
# T-Statistic = -0.5477225575051661
# P-Value = 0.6036450565101363
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
